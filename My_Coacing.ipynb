# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv(r"Upgrade.csv")

# %%
df.head()
# Out:
#    S.No.  Adjusted date Started  Charges  Student Name   Fees Date  Class  \
# 0      1           27.0     NaN      400  Akshara Soni  27/03/2023     10
# 1      2           12.0     NaN      400         Avani  12/03/2023     10
# 2      3           30.0     NaN      400       Princie  30/03/2023     10
# 3      4           27.0     NaN      400    Disha Jain  27/03/2023     10
# 4      5            2.0     NaN      400      Shivansh  02/03/2023      7
#
#     Time  CarryOver  Unnamed: 9  ...  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# 0  04:30     4100.0         NaN  ...          NaN          NaN          NaN
# 1  04:00     2000.0         NaN  ...          NaN          NaN          NaN
# 2  04:30     2400.0         NaN  ...          NaN          NaN          NaN
# 3  04:30     2800.0         NaN  ...          NaN          NaN          NaN
# 4  03:00     3600.0         NaN  ...          NaN          NaN          NaN
#
# ...

# %%
#Removing some unwanted columns starting from unnamed
cols_to_delete = [col for col in df.columns if col.startswith('Unnamed')]

# Drop the columns
df.drop(cols_to_delete, axis=1, inplace=True)

# %%
import seaborn as sns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   S.No.          54 non-null     int64
#  1   Adjusted date  16 non-null     float64
#  2   Started        44 non-null     object
#  3   Charges        54 non-null     int64
#  4   Student Name   54 non-null     object
#  5   Fees Date      15 non-null     object
#  6   Class          54 non-null     int64
#  7   Time           15 non-null     object
#  8   CarryOver      52 non-null     float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 3.9+ KB

# %%
df["Adjusted date"]=df["Adjusted date"].astype(float)
df["Fees Date"]=pd.to_datetime(df["Fees Date"],format='%d/%m/%Y')

# %%
df["Started"]=pd.to_datetime(df["Started"])
# Out:
# c:\Users\Hero\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# c:\Users\Hero\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25/11/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# c:\Users\Hero\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24/11/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
df.isnull().sum()
# Out:
# S.No.             0
# Adjusted date    38
# Started          10
# Charges           0
# Student Name      0
# Fees Date        39
# Class             0
# Time             39
# CarryOver         2
# dtype: int64

# %%
df.head(40)
# Out:
#     S.No.  Adjusted date    Started  Charges     Student Name  Fees Date  \
# 0       1           27.0        NaT      400     Akshara Soni 2023-03-27
# 1       2           12.0        NaT      400            Avani 2023-03-12
# 2       3           30.0        NaT      400          Princie 2023-03-30
# 3       4           27.0        NaT      400       Disha Jain 2023-03-27
# 4       5            2.0        NaT      400         Shivansh 2023-03-02
# 5       6           27.0        NaT      400          Sourabh 2023-03-27
# 6       7           10.0        NaT      400          Atharva 2023-04-10
# 7       8            2.0 2022-01-07      350          Drishti 2023-03-02
# 8       9            2.0 2021-11-12      350        Subhanshu 2023-03-02
# 9      10            2.0 2022-02-03      400            Lucky 2023-03-02
# 10     11            2.0 2022-02-03      400         Abhishek 2023-03-02
# 11     12           25.0 2023-03-25      400    Siddhi Bothra 2023-03-25
# ...

# %%
df.sort_values(by='CarryOver', inplace=True,ascending=False)
df.reset_index(drop=True, inplace=True)
df['S.No.'] = df.index + 1

# %%
df["Started"]=df["Started"].fillna(pd.to_datetime('05/06/2022'))
df["Adjusted date"]=df["Adjusted date"].fillna(2.0)
df["Fees Date"]=df["Fees Date"].fillna(pd.to_datetime('2022-3-2'))

# %%
df.head(40)
# Out:
#     S.No.  Adjusted date    Started  Charges     Student Name  Fees Date  \
# 0       1            2.0 2021-02-08      400            Dhruv 2022-03-02
# 1       2            2.0 2021-08-09      400   Tanisha Dhakad 2022-03-02
# 2       3            2.0 2021-11-12      350        Subhanshu 2023-03-02
# 3       4           27.0 2022-05-06      400     Akshara Soni 2023-03-27
# 4       5            2.0 2021-06-08      400      Sarthak God 2022-03-02
# 5       6            2.0 2021-10-25      350          Dhariya 2022-03-02
# 6       7            2.0 2021-11-24      350          Dishika 2022-03-02
# 7       8           14.0 2021-11-25      400     Ayaan Sheikh 2023-03-14
# 8       9            2.0 2022-05-06      400         Shivansh 2023-03-02
# 9      10            2.0 2022-01-07      500    Tanishq singh 2022-03-02
# 10     11            2.0 2021-11-15      400          Darshan 2022-03-02
# 11     12            2.0 2021-12-11      350           Hardik 2022-03-02
# ...

# %%
df["Time"].dtype
# Out:
# dtype('O')

# %%
#Checking again null values
df.isnull().sum()
# Out:
# S.No.             0
# Adjusted date     0
# Started           0
# Charges           0
# Student Name      0
# Fees Date         0
# Class             0
# Time             39
# CarryOver         2
# dtype: int64

# %%
# Convert "time" column to string data type
df["Time"] = df["Time"].astype(str)

# Fill null values with '00:00'
df["Time"].fillna('00:00', inplace=True)

# Convert "time" column to timedelta data type
df["Time"] = pd.to_timedelta(df["Time"] + ':00')

# Extract hours and minutes from timedeltas
df['hours'] = df["Time"].dt.components['hours']
df['minutes'] = df["Time"].dt.components['minutes']

# Format hours and minutes as strings with leading zeros
df["Time"] = df['hours'].apply(lambda x: f'{x:02d}') + ':' + df['minutes'].apply(lambda x: f'{x:02d}')

# Drop unnecessary columns
df.drop(['hours', 'minutes'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Hero\anaconda3\lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx:354, in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# File c:\Users\Hero\anaconda3\lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx:456, in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# ValueError: expecting hh:mm:ss format, received: nan:00
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Untitled-2.ipynb Cell 15 in <cell line: 8>()
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#Y101sdW50aXRsZWQ%3D?line=4'>5</a> df["Time"].fillna('00:00', inplace=True)
# ...

# %%
df.head()
# Out:
#    S.No.  Adjusted date    Started  Charges    Student Name  Fees Date  Class  \
# 0      1            2.0 2021-02-08      400           Dhruv 2022-03-02     10
# 1      2            2.0 2021-08-09      400  Tanisha Dhakad 2022-03-02      7
# 2      3            2.0 2021-11-12      350       Subhanshu 2023-03-02      8
# 3      4           27.0 2022-05-06      400    Akshara Soni 2023-03-27     10
# 4      5            2.0 2021-06-08      400     Sarthak God 2022-03-02      6
#
#     Time  CarryOver
# 0  00:00     6300.0
# 1  00:00     4600.0
# 2  03:00     4400.0
# 3  04:30     4100.0
# 4  00:00     4000.0

# %%
df.isnull().sum()
# Out:
# S.No.            0
# Adjusted date    0
# Started          0
# Charges          0
# Student Name     0
# Fees Date        0
# Class            0
# Time             0
# CarryOver        2
# dtype: int64

# %%
#As we see that 
df["CarryOver"]=df["CarryOver"].fillna(0.0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   S.No.          54 non-null     int64
#  1   Adjusted date  54 non-null     float64
#  2   Started        54 non-null     datetime64[ns]
#  3   Charges        54 non-null     int64
#  4   Student Name   54 non-null     object
#  5   Fees Date      54 non-null     datetime64[ns]
#  6   Class          54 non-null     int64
#  7   Time           54 non-null     object
#  8   CarryOver      54 non-null     float64
# dtypes: datetime64[ns](2), float64(2), int64(3), object(2)
# memory usage: 3.9+ KB

# %%
#checking duplicated value
df["Student Name"].value_counts()
# Out:
# Anant Chodhary     2
# Dhruv              1
# Arhan              1
# Tanishq\n          1
# Pradyuman\n        1
# Suhana             1
# Hitesh             1
# Mohit              1
# Amar               1
# Aditya D           1
# Pranav joshi       1
# Tanishka           1
# Anshraj            1
# Anubhav            1
# Vidhya             1
# Suhani Kabra       1
# Lakshika           1
# Prachi             1
# Lakshya Purohit    1
# Siddhi Jain        1
# Uttam              1
# Lakshya            1
# Harsh Bairagi      1
# Anupam(5th)        1
# Kashish            1
# Siddhi Bothra      1
# Aditi              1
# Vishal             1
# Tanisha Dhakad     1
# Lucky              1
# Subhanshu          1
# Akshara Soni       1
# Sarthak God        1
# Dhariya            1
# Dishika            1
# Ayaan Sheikh       1
# Shivansh           1
# Tanishq singh      1
# Darshan            1
# Hardik             1
# Abhishek           1
# Dheeraj junwal     1
# Atharva            1
# ...

# %%
df[df['Student Name']=="Anant Chodhary"]
# Out:
#     S.No.  Adjusted date    Started  Charges    Student Name  Fees Date  \
# 22     23            2.0 2021-10-28      350  Anant Chodhary 2022-03-02
# 37     38            2.0 2021-10-28      350  Anant Chodhary 2022-03-02
#
#     Class   Time  CarryOver
# 22      8  00:00     2050.0
# 37      7  00:00      800.0

# %%
#I have two values for anant chodhary so i have merged it in one and i am dropping one anant choudhary after
#adding both carryovers.
df.loc[df["S.No."]==38,'CarryOver']=2850
df = df[df['S.No.'] != 23].reset_index(drop=True)

# %%
df[df['Student Name']=="Anant Chodhary"]
# Out:
#     S.No.  Adjusted date    Started  Charges    Student Name  Fees Date  \
# 36     38            2.0 2021-10-28      350  Anant Chodhary 2022-03-02
#
#     Class   Time  CarryOver
# 36      7  00:00     2850.0

# %%
df.sort_values(by='CarryOver', inplace=True,ascending=False)

# %%
#Visualizing which student has given me how much fees.
from matplotlib.ticker import FuncFormatter

plt.figure(figsize=(14,10))
sns.barplot(df["Student Name"],df["CarryOver"])
plt.xticks(rotation='vertical')
def format_y_axis(y, _):
    return f'₹{y}'

# Use FuncFormatter to apply the custom formatting to y-axis labels
formatter = FuncFormatter(format_y_axis)
plt.gca().yaxis.set_major_formatter(formatter)
for i, v in enumerate(df['CarryOver']):
    plt.text(i, v, str(v), ha='center', va='bottom',rotation="vertical")
plt.show()
# Out:
# c:\Users\Hero\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ax = sns.histplot(df['Adjusted date'], kde=False,bins=7)

# Get the counts of each bin in the histogram
#counts, bins, _ = ax.hist(df['Adjusted date'], bins=range(min(df['Adjusted date']), max(df['Adjusted date'])+1), edgecolor='black')

# Add count values above the histogram bars
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='baseline', color='black')

# Add x-axis labels below the histogram bars
for i, bin_width in enumerate(ax.get_xticks()[1:]):
    ax.annotate(f'{int(bin_width)}', (ax.patches[i].get_x() + ax.patches[i].get_width() / 2., -0.1), 
                ha='center', va='top', color='black')


plt.show()
# I WAS STUCK HERE AS I WAS NOT GETTING THE DESIRED GRAPH THAT I WANTED TO SEE SO I TOOK THE HELP 
# OF CHATGPT, AND IT SUGGESTED THAT I SHOULD TRY COUNTPLOT. AND NOW I TRIED COUNT PLOT AND SEE MY RESULT
#IN THE NEXT CODE CELL

# %%
ax = sns.countplot(x=df["Adjusted date"], data=df)

# Set labels for x-axis and y-axis
ax.set_xlabel('Value')
ax.set_ylabel('Count')
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='baseline', color='black')

# %%
plt.figure(figsize=(20,16))
explode = [0.1] * len(df["Adjusted date"].value_counts().index)
plt.pie(df["Adjusted date"].value_counts().values,autopct='%1.1f%%', startangle=90,labeldistance=0.7,explode=explode)
plt.legend(labels=df["Adjusted date"].value_counts().index)
plt.show()

# %%
df.head()
# Out:
#    S.No.  Adjusted date    Started  Charges    Student Name  Fees Date  Class  \
# 0      1            2.0 2021-02-08      400           Dhruv 2022-03-02     10
# 1      2            2.0 2021-08-09      400  Tanisha Dhakad 2022-03-02      7
# 2      3            2.0 2021-11-12      350       Subhanshu 2023-03-02      8
# 3      4           27.0 2022-05-06      400    Akshara Soni 2023-03-27     10
# 4      5            2.0 2021-06-08      400     Sarthak God 2022-03-02      6
#
#     Time  CarryOver
# 0  00:00     6300.0
# 1  00:00     4600.0
# 2  03:00     4400.0
# 3  04:30     4100.0
# 4  00:00     4000.0

# %%
df["Adjusted date"]=df["Adjusted date"].astype(int)

# %%
df["Adjusted date"].value_counts()
# Out:
# 2     43
# 27     3
# 12     2
# 25     2
# 14     1
# 10     1
# 30     1
# Name: Adjusted date, dtype: int64

# %%
df.head()
#X["Time"]= pd.to_datetime(X["Time"], format="%H:%M").dt.time
# Out:
#    S.No.  Adjusted date  Started  Charges    Student Name  Fees Date  Class  \
# 0      1            2.0        0      400           Dhruv          0     10
# 1      2            2.0        4      400  Tanisha Dhakad          0      7
# 2      3            2.0        9      350       Subhanshu          1      8
# 3      4           27.0       18      400    Akshara Soni          5     10
# 4      5            2.0        2      400     Sarthak God          0      6
#
#    Time  CarryOver
# 0     4     6300.0
# 1     4     4600.0
# 2     0     4400.0
# 3     2     4100.0
# 4     4     4000.0

# %%
y.head()
# Out:
# 0    6300.0
# 1    4600.0
# 2    4400.0
# 3    4100.0
# 4    4000.0
# Name: CarryOver, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   S.No.          54 non-null     int64
#  1   Adjusted date  54 non-null     float64
#  2   Started        54 non-null     int64
#  3   Charges        54 non-null     int64
#  4   Student Name   54 non-null     object
#  5   Fees Date      54 non-null     int64
#  6   Class          54 non-null     int64
#  7   Time           54 non-null     int64
#  8   CarryOver      52 non-null     float64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 3.9+ KB

# %%
#Here as we see that the Time column is of object type time stamp which can not work in Rf.fit()
#So i think this needs to be label encoded
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["Time"]=le.fit_transform(df["Time"])
df["Fees Date"]=le.fit_transform(df["Fees Date"])
df["Started"]=le.fit_transform(df["Started"])

# %%
df["Student Name"]=le.fit_transform(df["Student Name"])

# %%
df["CarryOver"].fillna(df["CarryOver"].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# S.No.            0
# Adjusted date    0
# Started          0
# Charges          0
# Student Name     0
# Fees Date        0
# Class            0
# Time             0
# CarryOver        0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X=df.drop(columns=["CarryOver"])
y=df["CarryOver"]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=42)

# %%
pd.DataFrame(y_train)
pd.DataFrame(y_test)
#y_train=y_train.dropna()
#y_test=y_test.dropna()
# Out:
#       CarryOver
# 19  2400.000000
# 49     0.000000
# 48   200.000000
# 12  2800.000000
# 44   350.000000
# 5   3900.000000
# 17  2800.000000
# 52  1979.807692
# 3   4100.000000

# %%
y_train
# Out:
# 32    1400.000000
# 13    2800.000000
# 8     3600.000000
# 26    1750.000000
# 6     3700.000000
# 34    1350.000000
# 4     4000.000000
# 37     800.000000
# 24    2000.000000
# 45     350.000000
# 33    1400.000000
# 50       0.000000
# 15    2800.000000
# 9     3500.000000
# 16    2800.000000
# 30    1400.000000
# 36    1200.000000
# 25    1800.000000
# 11    2950.000000
# 0     6300.000000
# 47     300.000000
# 27    1600.000000
# 31    1400.000000
# 40     400.000000
# 29    1600.000000
# 46     350.000000
# 1     4600.000000
# 21    2100.000000
# 2     4400.000000
# 41     400.000000
# 39     500.000000
# 35    1350.000000
# 23    2000.000000
# 43     350.000000
# 10    3200.000000
# 22    2050.000000
# 18    2450.000000
# 53    1979.807692
# 20    2400.000000
# 7     3600.000000
# 42     400.000000
# 14    2800.000000
# 28    1600.000000
# 51       0.000000
# 38     650.000000
# Name: CarryOver, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor()
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
pred=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
r2 = r2_score(y_test, pred)
print(r2)
# Out:
# 0.9499678670955782

# %%
new_data = {'S.No.':55,'Adjusted date':16.0,'Started':2,'Charges':800,'Student Name':51,'Fees Date':1,'Class':10,"Time":3}
new_data_df = pd.DataFrame(new_data, index=[0])
new_pred = model.predict(new_data_df)

print("Prediction on new data:", new_pred)
# Out:
# Prediction on new data: [708.64423077]
